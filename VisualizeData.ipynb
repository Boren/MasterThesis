# %%
# %matplotlib inline

from pylab import *
from matplotlib.pyplot import figure, plot, xlabel, ylabel, title, show
from numpy import linspace

# %%
import data_loader
generator = data_loader.Generator()

# %%
training_image = "6010_1_2"

# %%
generator.save_overlay(training_image, f"images/{training_image}_overlay.png", view = True)

# %%
generator.save_image(training_image, f"images/{training_image}.png", view = True)
